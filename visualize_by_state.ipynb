# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr

# %%
df = pd.read_csv('data/processed/landings_processed.csv')
df.head()
# Out:
#    Year                          Port  Millions of Pounds State
# 0  2017              Dutch Harbor, AK               768.7    AK
# 1  2017  Aleutian Islands (Other), AK               552.3    AK
# 2  2017                    Kodiak, AK               530.4    AK
# 3  2017                 Reedville, VA               319.9    VA
# 4  2017     Pascagoula-Moss Point, MS               301.3    MS

# %%
df_AK = df[df['State'] == 'AK']
df_AL = df[df['State'] == 'AL']
df_CA = df[df['State'] == 'CA']
df_CT = df[df['State'] == 'CT']
df_FL = df[df['State'] == 'FL']
df_GA = df[df['State'] == 'GA']
df_HI = df[df['State'] == 'HI']
df_LA = df[df['State'] == 'LA']
df_MA = df[df['State'] == 'MA']
df_MD = df[df['State'] == 'MD']
df_ME = df[df['State'] == 'ME']
df_MS = df[df['State'] == 'MS']
df_NC = df[df['State'] == 'NC']
df_NH = df[df['State'] == 'NH']
df_NJ = df[df['State'] == 'NJ']
df_NY = df[df['State'] == 'NY']
df_OR = df[df['State'] == 'OR']
df_RI = df[df['State'] == 'RI']
df_SC = df[df['State'] == 'SC']
df_TX = df[df['State'] == 'TX']
df_VA = df[df['State'] == 'VA']
df_WA = df[df['State'] == 'WA']

# %%
plt.scatter(df_AK['Year'], df_AK['Millions of Pounds'])

# %%
plt.scatter(df_AL['Year'], df_AL['Millions of Pounds'])

# %%
plt.scatter(df_CA['Year'], df_CA['Millions of Pounds'])

# %%
plt.scatter(df_CT['Year'], df_CT['Millions of Pounds'])

# %%
plt.scatter(df_FL['Year'], df_FL['Millions of Pounds'])

# %%
plt.scatter(df_GA['Year'], df_GA['Millions of Pounds'])

# %%
plt.scatter(df_HI['Year'], df_HI['Millions of Pounds'])

# %%
plt.scatter(df_LA['Year'], df_LA['Millions of Pounds'])

# %%
plt.scatter(df_MA['Year'], df_MA['Millions of Pounds'])

# %%
plt.scatter(df_MD['Year'], df_MD['Millions of Pounds'])

# %%
plt.scatter(df_ME['Year'], df_ME['Millions of Pounds'])

# %%
plt.scatter(df_MS['Year'], df_MS['Millions of Pounds'])

# %%
plt.scatter(df_NC['Year'], df_NC['Millions of Pounds'])

# %%
plt.scatter(df_NH['Year'], df_NH['Millions of Pounds'])

# %%
plt.scatter(df_NJ['Year'], df_NJ['Millions of Pounds'])

# %%
plt.scatter(df_NY['Year'], df_NY['Millions of Pounds'])

# %%
plt.scatter(df_OR['Year'], df_OR['Millions of Pounds'])

# %%
plt.scatter(df_RI['Year'], df_RI['Millions of Pounds'])

# %%
plt.scatter(df_SC['Year'], df_SC['Millions of Pounds'])

# %%
plt.scatter(df_TX['Year'], df_TX['Millions of Pounds'])

# %% [markdown]
# plt.scatter(df_VA['Year'], df_VA['Millions of Pounds'])

# %%
plt.scatter(df_WA['Year'], df_WA['Millions of Pounds'])

# %%
plt.scatter(df_VA['Year'], df_VA['Millions of Pounds'])
